# %%
from __future__ import division #safeguard against evil floor division
import numpy as np
from scipy import linalg as la
import matplotlib.pyplot as plt
import timeit
np.set_printoptions(suppress=False)

# %%
plt.figure(figsize=(20,4))
plt.xlabel('Number of even coupling constants included')
plt.ylabel('Thermal Eigenvalue yT')
p8 = plt.plot([0.88213852,0.95997822,0.96333859,0.95932521,0.96106577,0.96105902,0.96185279],'.',label='Inline label')
p8.legend()
plt.plot([0.88213852,1.05997822,0.96333859,0.95932521,0.96106577,0.96105902,0.96185279],'.')
plt.savefig('RG1.png',bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-05d1d7c3ba14> in <module>
#       3 plt.ylabel('Thermal Eigenvalue yT')
#       4 p8 = plt.plot([0.88213852,0.95997822,0.96333859,0.95932521,0.96106577,0.96105902,0.96185279],'.',label='Inline label')
# ----> 5 p8.legend()
#       6 plt.plot([0.88213852,1.05997822,0.96333859,0.95932521,0.96106577,0.96105902,0.96185279],'.')
#       7 plt.savefig('RG1.png',bbox_inches='tight')
#
# AttributeError: 'list' object has no attribute 'legend'
